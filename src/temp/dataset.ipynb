# %%
import pandas as pd
scholar_df = pd.DataFrame({
    "scholar_id": [1, 2, 3, 4],
    "research_interests": [
        "deep learning for flood prediction and hydrological modelling",
        "computer vision and medical image analysis",
        "structural health monitoring using machine learning",
        "remote sensing and climate change"
    ],
    "expertise": [
        "deep learning, hydrology, remote sensing",
        "computer vision, deep learning, medical imaging",
        "machine learning, structural engineering, sensors",
        "remote sensing, GIS, climate modelling"
    ],
    "department": ["Civil Engineering","Computer Science","Civil Engineering","Civil Engineering"],
    "university": ["IIT Kharagpur","IIT Delhi","IIT Bombay","IIT Kharagpur"],
    "country": ["India","India","India","India"],
    "publication_count": [  12, 25, 18, 30],
    "citation_count": [ 120, 450, 200, 600],
    "years_experience": [ 2, 5, 3, 7 ]
})

# %%
scholar_df
# Out:
#    scholar_id                                 research_interests  \
# 0           1  deep learning for flood prediction and hydrolo...
# 1           2         computer vision and medical image analysis
# 2           3  structural health monitoring using machine lea...
# 3           4                  remote sensing and climate change
#
#                                            expertise         department  \
# 0           deep learning, hydrology, remote sensing  Civil Engineering
# 1    computer vision, deep learning, medical imaging   Computer Science
# 2  machine learning, structural engineering, sensors  Civil Engineering
# 3             remote sensing, GIS, climate modelling  Civil Engineering
#
#       university country  publication_count  citation_count  years_experience
# 0  IIT Kharagpur   India                 12             120                 2
# 1      IIT Delhi   India                 25             450                 5
# ...

# %%
scholar_df.columns
# Out:
# Index(['scholar_id', 'research_interests', 'expertise', 'department',
#        'university', 'country', 'publication_count', 'citation_count',
#        'years_experience'],
#       dtype='object')

# %%
df = pd.read_json(r"C:\Users\ps302\OneDrive\Desktop\Recommend\phd_academic_sops_2000.json")
df.head()
# Out:
#                  name                                 research_interests  \
# 0       Maya L. Patel  [Autonomous navigation for aerial robotics, Mu...
# 1  Alejandro R. Gómez  [Satellite remote sensing for climate change m...
# 2          Aisha Khan  [Autonomous navigation for aerial robotics, Mu...
# 3       Mateo Alvarez  [Satellite remote sensing for environmental mo...
# 4        Aria L. Chen  [Robust perception for autonomous aerial vehic...
#
#                                            expertise  \
# 0  [Python, C++, Robot Operating System (ROS), Te...
# 1  [Python, R, MATLAB, Google Earth Engine, ENVI,...
# 2  [Python, C++, Robot Operating System (ROS), Te...
# 3  [Python (NumPy, Pandas, Scikit‑learn), R (sp, ...
# 4  [Python, C++, ROS2, TensorFlow, PyTorch, JAX, ...
#
#                                     department  \
# 0          Electrical and Computer Engineering
# 1          Civil and Environmental Engineering
# 2          Electrical and Computer Engineering
# ...

# %%
df.columns
# Out:
# Index(['name', 'research_interests', 'expertise', 'department', 'university',
#        'country', 'publications', 'publication_count', 'citation_count',
#        'years_experience', 'sop_paragraphs', 'category', 'sub_domain',
#        'scholar_id', 'source_file', 'sop_paragraphs_json', 'full_sop_markdown',
#        'word_count'],
#       dtype='object')

# %%
gpt = {'name', 'research_interests', 'expertise', 'department', 'university',
       'country', 'publications', 'publication_count', 'citation_count',
       'years_experience', 'sop_paragraphs', 'category', 'sub_domain',
       'scholar_id', 'source_file', 'sop_paragraphs_json', 'full_sop_markdown',
       'word_count'}

act = {'scholar_id', 'research_interests', 'expertise', 'department',
       'university', 'country', 'publication_count', 'citation_count',
       'years_experience'}

common = gpt & act
isym = gpt | act
print(isym)
# Out:
# {'country', 'full_sop_markdown', 'publication_count', 'research_interests', 'citation_count', 'years_experience', 'scholar_id', 'publications', 'source_file', 'department', 'university', 'name', 'category', 'word_count', 'sub_domain', 'sop_paragraphs', 'expertise', 'sop_paragraphs_json'}

# %%
union_ = {'country', 'full_sop_markdown', 'publication_count', 'research_interests', 
'citation_count', 'years_experience', 'scholar_id', 'publications', 'source_file', 
'department', 'university', 'name', 'category', 'word_count', 'sub_domain', 
'sop_paragraphs', 'expertise', 'sop_paragraphs_json'}

common = {'country', 'publication_count', 'research_interests', 'years_experience', 
'citation_count', 'scholar_id', 'expertise', 'department', 'university'}

different = {'name', 'category', 'word_count', 'full_sop_markdown', 'sub_domain',
 'publications', 'sop_paragraphs', 'sop_paragraphs_json', 'source_file'}
